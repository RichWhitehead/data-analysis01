# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# COVID-19 CASES AND DEATH BY RACE/ETHNICITY
cov_df = pd.read_csv("COVID-19_Cases_and_Deaths_by_Race_Ethnicity.csv")
cov_df.head
# Out:
# <bound method NDFrame.head of     Date updated  Race/ethnicity  Total population  Total cases  \
# 0     04/20/2020        Hispanic          589809.0         2269
# 1     04/20/2020        NH Asian          187532.0          215
# 2     04/20/2020        NH Black          387134.0         1823
# 3     04/20/2020        NH Other               0.0          118
# 4     04/20/2020        NH White         2408190.0         5101
# ..           ...             ...               ...          ...
# 377   07/08/2020        NH Black          387134.0         6176
# 378   07/08/2020  NH Multiracial               NaN          131
# 379   07/08/2020        NH Other               NaN          266
# 380   07/08/2020        NH White         2408190.0        16597
# 381   07/08/2020         Unknown               NaN        14353
#
#      Crude case rate per 100k  Age adjusted case rate per 100k  Total deaths  \
# 0                       385.0                              NaN           109
# ...

# %%
x = cov_df["Race/ethnicity"]
y = cov_df["Total population"]
z = cov_df["Total deaths"]

# %%
x
# Out:
# 0            Hispanic
# 1            NH Asian
# 2            NH Black
# 3            NH Other
# 4            NH White
#             ...
# 377          NH Black
# 378    NH Multiracial
# 379          NH Other
# 380          NH White
# 381           Unknown
# Name: Race/ethnicity, Length: 382, dtype: object

# %%
y
# Out:
# 0       589809.0
# 1       187532.0
# 2       387134.0
# 3            0.0
# 4      2408190.0
#          ...
# 377     387134.0
# 378          NaN
# 379          NaN
# 380    2408190.0
# 381          NaN
# Name: Total population, Length: 382, dtype: float64

# %%
z
# Out:
# 0       109
# 1        14
# 2       184
# 3        11
# 4       845
#        ...
# 377     646
# 378      27
# 379      16
# 380    3184
# 381      50
# Name: Total deaths, Length: 382, dtype: int64

# %%
plt.figure()
x1 = [100, 200, 400, 800, 1600, 2400]
x2 = [25, 41, 67, 220, 597, 1100]
x3 = [0, 11, 14, 200, 650, 900]
plt.plot(x1, label="Race")
plt.plot(x2, label="Total Population")
plt.plot(x3, label="Total Deaths")
plt.legend()
plt.show()

# %%
sns.set()
